# %%
# all of the following are equivalent
my_string = 'Hello1'
print(my_string)

my_string = "Hello2"
print(my_string)

my_string = '''Hello3'''
print(my_string)

# triple quotes string can extend multiple lines
my_string = """Hello4, welcome to
           the world of Python"""
print(my_string)
# Out:
# Hello1
# Hello2
# Hello3
# Hello4, welcome to
#            the world of Python

# %%
str = ' data science class has started ... seems like confusing'

# %%
str[0]
# Out:
# ' '

# %%
len(str)
# Out:
# 56

# %%
my_string = "Welcome to Etlhive"

# %%
# access characters in a string
# index must be in range
my_string[150]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-707c74b7ba5c> in <module>
#       1 # access characters in a string
#       2 # index must be in range
# ----> 3 my_string[150]
#
# IndexError: string index out of range

# %%
# index must be an integer
my_string[1.5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3a01696fb2a1> in <module>()
#       1 # index must be an integer
# ----> 2 my_string[1.5]
#
# TypeError: string indices must be integers

# %%
# change or delete a string
# Strings are immutable. This means that elements of a string cannot be 
# changed once it has been assigned.

# %%
my_string[5]
# Out:
# 'a'

# %%
my_string = 'Python'

# %%
del my_string

# %%
# concatenation
str1 = 'Hello '
str2 ='World !'

# using +
print('str1 + str2 = ', str1 + str2)

# using *
print('str1 * 3 =', str1 * 3)
# Out:
# str1 + str2 =  Hello World !
# str1 * 3 = Hello Hello Hello

# %%
# iterating
count = 0
for letter in 'Hello World how r you':
    count += 1 
    #count = count + 1
    
print(count,'letters found')
# Out:
# 21 letters found

# %%
my_string = " Hello How are you"

'are' in my_string
# Out:
# True

# %%
'Hello' in my_string
# Out:
# True

# %%
# Python String Formatting
print("He said, \"What\'s there?\"")
# Out:
# He said, "What's there?"

# %%
# default(implicit) order
default_order = "{}, {} and {}".format('John','Bill','Sean')

print(default_order)
# Out:
# John, Bill and Sean

# %%
# order using positional argument
positional_order = "{2}, {1} and {2}".format('John','Bill','Sean')
print('\n--- Positional Order ---')
print(positional_order)
# Out:
# --- Positional Order ---
# Sean, Bill and Sean

# %%
# order using keyword argument
keyword_order = "{s1}, {s1} and {j1}".format(j1='John',b1='Bill',s1='Sean')
print('\n--- Keyword Order ---')
print(keyword_order)
# Out:
# --- Keyword Order ---
# Sean, Sean and John

# %%
# float formatting

%10.2

a = 10.76
b = 220.5666666
print("Two float numbers : {} & {}".format(a, b))
print("Two float numbers : {:.2f} & {:.2f}".format(a, b))
print("Two float numbers : {:.2f} & {:10.2f}".format(a, b))
# Out:
# ERROR:root:Line magic function `%10.2` not found.
# Two float numbers : 10.76 & 220.5666666
# Two float numbers : 10.76 & 220.57
# Two float numbers : 10.76 &     220.57

# %%
name = "John"
age = 23
print("%s is %d years old." % (name, age))
# Out:
# John is 23 years old.

# %%
data = ("John", "Doe", 53.44)
format_string = "Hello %s %s. Your current balance is $%s."

print(format_string % data)
# Out:
# Hello John Doe. Your current balance is $53.44.

# %%
# integer arguments
print("The number is: {:d}".format(123))

# float arguments
print("The float number is: {:f}".format(123.4567898))

# octal, binary and hexadecimal format
print("bin: {0:b}, oct: {0:o}, hex: {0:x}".format(12))
# Out:
# The number is: 123
# The float number is: 123.456790
# bin: 1100, oct: 14, hex: c

# %%
# string padding with left alignment
print("{:5}".format("cat"))

# string padding with right alignment
print("{:>5}".format("cat"))

# string padding with center alignment
print("{:^5}".format("cat"))

# string padding with center alignment
# and '*' padding character
print("{:*^7}".format("cat"))
# Out:
# cat
#   cat
#  cat
# **cat**

# %%
# String Slicing Operations
a = "Python is easy!"

# %%
# a["Starting pt:Ending pt"]
a[0:6]
# Out:
# 'Python'

# %%
a[10:15]
# Out:
# 'easy!'

# %%
# Reverse String
a[-5:-1]
# Out:
# 'easy'

# %%
# a["Start index:End index:Steps"]
a[::-1]
# reversing of string
# Out:
# '!ysae si nohtyP'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# capitalize()	Converts the first character to upper case
b = "dadlloo"
b.capitalize()
# Out:
# 'Dadlloo'

# %%
# count() :- gives the count of a specific value of a string
b.count("o")
# Out:
# 2

# %%
# find()	Searches the string for a specified value and returns the position of where it was found
b.find("o")
# Out:
# 5

# %%
# Diffrence between index,find
b.index("w")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-cb7452ce776e> in <module>
#       1 # Diffrence between index,find
# ----> 2 b.index("w")
#
# ValueError: substring not found

# %%
# isalpha()	Returns True if all characters in the string are in the alphabet
c = "ABCDEFG"
c.isalpha()
# Out:
# True

# %%
d = "Hey88"
d.isalpha()
# Out:
# False

# %%
# isdecimal()	Returns True if all characters in the string are decimals
d = "23"
d.isdecimal()
# Out:
# True

# %%
# islower()	Returns True if all characters in the string are lower case
f = "vvffggg"
f.islower()
# Out:
# True

# %%
# isupper()	Returns True if all characters in the string are upper case
g = "HHYYTTCSS"
g.isupper()
# Out:
# True

# %%
# replace()	Returns a string where a specified value is replaced with a specified value
g.replace("H","L")
# Out:
# 'LLYYTTCSS'

# %%
# split()	Splits the string at the specified separator, and returns a list
g.split("Y")
# Out:
# ['HH', '', 'TTCSS']

# %%
a = "Hello"
b = "World"
a + b
# Out:
# 'HelloWorld'

# %%
a + b*2
# Out:
# 'HelloWorldWorld'
